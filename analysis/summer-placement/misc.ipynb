# %%
observables = {
    "dEdX_median": apply_track_operation(mc.recoParticles.track_dEdX, np.median),
    "dEdX_mean": ak.mean(mc.recoParticles.track_dEdX, axis=-1),
    "dQdX_median": apply_track_operation(mc.recoParticles.track_dQdX, np.median),
    "dQdX_mean": ak.mean(mc.recoParticles.track_dQdX, axis=-1),
    "residual_range_median": apply_track_operation(mc.recoParticles.residual_range, np.median),
    "residual_range_mean": ak.mean(mc.recoParticles.residual_range, axis=-1),
    "chi2_proton": mc.recoParticles.track_chi2_proton / mc.recoParticles.track_chi2_proton_ndof,
    "chi2_pion": mc.recoParticles.track_chi2_pion / mc.recoParticles.track_chi2_pion_ndof,
    "chi2_muon": mc.recoParticles.track_chi2_muon / mc.recoParticles.track_chi2_muon_ndof,
    "track_len": mc.recoParticles.track_len,
    "track_score": mc.recoParticles.track_score,
    "track_vertex_michel": mc.recoParticles.track_vertex_michel,
    "track_vertex_nhits": mc.recoParticles.track_vertex_nhits,
    "hit_density": mc.recoParticles.n_hits_collection / mc.recoParticles.track_len
    }
