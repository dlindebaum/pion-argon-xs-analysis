# %%
particle_PDG = {
    # Baryons
    2212: "proton",
    2112: "neutron",
    3112: "sigma-",

    # Mesons
    211: "pi+",
    -211: "pi-",
    111: "pi0",
    321: "kaon+",
    -321: "kaon-",
    130: "kaon0L",
    310: "kaon0S",
    3112: "pi0",

    # Leptons
    11: "electron",
    -11: "positron",
    13: "mu-",
    -13: "mu+",
    
    # Bosons
    22: "photon",

    # Nuclei
    1000010020: "deuteron",
    1000020030: "triton",
    1000010030: "he3",
    1000100200: "neon-20",
    1000020040: "alpha",
    1000180400: "argon-40",
    1000060120: "carbon-12",
}
